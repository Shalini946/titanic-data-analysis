# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: seaborn in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (0.13.2)
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19744\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sn

# %%
import matplotlib as pl

# %%
data=pd.read_csv(r"titanic_data.csv")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C
# 2            3         1       3  female  26.0      0      0   7.9250        S
# 3            4         1       1  female  35.0      1      0  53.1000        S
# 4            5         0       3    male  35.0      0      0   8.0500        S

# %%
data.shape
# Out:
# (891, 9)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Fare', 'Embarked'],
#       dtype='object')

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Fare           float64
# Embarked        object
# dtype: object

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C
# 2            3         1       3  female  26.0      0      0   7.9250        S
# 3            4         1       1  female  35.0      1      0  53.1000        S
# 4            5         0       3    male  35.0      0      0   8.0500        S

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
data['Survived'].nunique()
# Out:
# 2

# %%
data['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Fare         891 non-null    float64
#  8   Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 62.8+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
pip install matplotlib --upgrade
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
pl=data.Survived.value_counts().plot(kind='bar')

# %%
pl.set_xlabel('survived or not')
# Out:
# Text(0.5, 24.0, 'survived or not')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C
# 2            3         1       3  female  26.0      0      0   7.9250        S
# 3            4         1       1  female  35.0      1      0  53.1000        S
# 4            5         0       3    male  35.0      0      0   8.0500        S

# %%
#passanger class

# %%
data.Pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
data.Pclass.nunique()
# Out:
# 3

# %%
data[['Pclass','Survived']].groupby('Pclass').count()
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %%
data[['Pclass','Survived']].groupby('Pclass').mean().Survived.plot(kind='bar',title='Prob chance')
# Out:
# <Axes: title={'center': 'Prob chance'}, xlabel='Pclass'>

# %%
data.Sex.value_counts().sort_index().plot(kind='bar',title='Sex')
# Out:
# <Axes: title={'center': 'Sex'}, xlabel='Sex'>

# %%
data[['Sex','Survived']].groupby('Sex').mean().Survived.plot(kind='pie',title='Survival probabaility')
# Out:
# <Axes: title={'center': 'Survival probabaility'}, ylabel='Survived'>

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C
# 2            3         1       3  female  26.0      0      0   7.9250        S
# 3            4         1       1  female  35.0      1      0  53.1000        S
# 4            5         0       3    male  35.0      0      0   8.0500        S

# %%
data.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
data.Embarked.nunique()
# Out:
# 3

# %%
data.Embarked.value_counts().sort_index().plot(kind='pie',y='count',autopct='%1.0f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sn.catplot(x='Sex',y='Survived',hue='Pclass',kind='bar',data=data)

# %%
sn.scatterplot(x='Age',y='Fare',hue='Sex',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sn.scatterplot(x='Age',y='Fare',hue='Sex',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sn.lineplot(x='Age',y='Fare',hue='Sex',style='Sex',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sn.boxplot(x='Survived',y='Age',data=data)
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
data.isna().sum()*100/len(data)
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Fare            0.000000
# Embarked        0.224467
# dtype: float64

# %%
data=data.drop(columns=['PassengerId'])

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
data['Age']=data['Age'].fillna(data['Age'].mean())

# %%
data['Embarked']=data['Embarked'].fillna(2)

# %%
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
from sklearn.impute import SimpleImputer
im= SimpleImputer(missing_values=np.nan,strategy='mean')

age_data=im.fit_transform(age_data)

# %%
age_data

# %%
#encoding

# %%
data['Sex']= data['Sex'].map({'male':0,'female':1})

# %%
data.Sex
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 886   NaN
# 887   NaN
# 888   NaN
# 889   NaN
# 890   NaN
# Name: Sex, Length: 891, dtype: float64
